# %% [markdown]
# [teks link](https://)

# %% [markdown]
# **Weekly Exercise 1**

# %%
Panjang = 20.5
Lebar = 25
Tinggi = 10

Keliling = 2 * (panjang + lebar)
Luas = panjang * lebar
Volume = panjang * lebar * tinggi

print("panjang = ", Panjang)
print("lebar = ", Lebar)
print("tinggi = ", Tinggi)
print("keliling = ", Keliling)
print("volume = ", Volume)
# Out:
# panjang =  20.5
# lebar =  25
# tinggi =  10
# keliling =  91.0
# volume =  5125.0

# %% [markdown]
# **Weekly Exercise 2**

# %%
rata_shafira = (85 + 75)//2
print("Rata-rata nilai Shafira pada kedua mata kuliah = ", rata_shafira)

nilai_hanif = 75 + 90
nilai_andi = 70 + 75
nilai_hanifandi = nilai_hanif + nilai_andi
print("\nJumlah nilai Hanif = ", nilai_hanif)
print("\nJumlah nilai Andi = ", nilai_andi)
print("\nJumlah nilai Hanif dan Andi untuk semua mata kuliah = ", nilai_hanifandi)

rata_wdhn_k = (85 + 85 + 80 + 95)/4
rata_wdhn_s = (85 + 85 + 75 + 80)/4
print("\nJumlah rata-rata nilai kalkulus Widya, Dhanar, Hikma, dan Nedia = ", rata_wdhn_k)
print("\nJumlah rata-rata nilai statistika Widya, Dhanar, Hikma, dab Nedia = ", rata_wdhn_s)

rata_kalkulus = (85+80+75+95+85+75+70+85+80)/9
print("\nJumlah rata-rata nilai kalkulus = ", rata_kalkulus)

rata_statistika = (75+90+80+80+85+90+75+85+75)/9
print("\nJumlah rata-rata nilai statistika = ", rata_statistika)
# Out:
# Rata-rata nilai Shafira pada kedua mata kuliah =  80
#
# Jumlah nilai Hanif =  165
#
# Jumlah nilai Andi =  145
#
# Jumlah nilai Hanif dan Andi untuk semua mata kuliah =  310
#
# Jumlah rata-rata nilai kalkulus Widya, Dhanar, Hikma, dan Nedia =  86.25
#
# Jumlah rata-rata nilai statistika Widya, Dhanar, Hikma, dab Nedia =  81.25
#
# Jumlah rata-rata nilai kalkulus =  81.11111111111111
#
# Jumlah rata-rata nilai statistika =  81.66666666666667

# %% [markdown]
# **Weekly Exercise 3**

# %%
gaji_dwi_agustus = (31-3)*30000*8
tunjangan = int(10/100*gaji_dwi)
lembur = (5*10000)
gaji_total = gaji_dwi_agustus + tunjangan + lembur

print("Gaji pada bulan Agustus jika Dwi tidak masuk kerja selama 3 hari = Rp", gaji_dwi_agustus)
print("\nJumlah tunjangan yang diterima oleh Dwi di bulan Agustus = Rp", tunjangan)
print("\nJumlah upah lembur yang diterima oleh Dwi di bulan Agustus = Rp", lembur)
print("\nJumlah gaji total yang diterima oleh Dwi di bulan Agustus = Rp", gaji_total)
# Out:
# Gaji pada bulan Agustus jika Dwi tidak masuk kerja selama 3 hari = Rp 6720000
#
# Jumlah tunjangan yang diterima oleh Dwi di bulan Agustus = Rp 672000
#
# Jumlah upah lembur yang diterima oleh Dwi di bulan Agustus = Rp 50000
#
# Jumlah gaji total yang diterima oleh Dwi di bulan Agustus = Rp 7442000
